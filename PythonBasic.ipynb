# %%
from Helper import launch_code

# %%
print(launch_code())
# Out:
# 987654321

# %%
# !pip install requests

# %%
# !pip list
# Out:
# Package                           Version
# --------------------------------- --------------------
# aext-assistant                    4.20.0
# aext-assistant-server             4.20.0
# aext-core                         4.20.0
# aext-core-server                  4.20.0
# aext_environments_server          4.20.0
# aext-panels                       4.20.0
# aext-panels-server                4.20.0
# aext-project-filebrowser-server   4.20.0
# aext-share-notebook               4.20.0
# aext-share-notebook-server        4.20.0
# aext-shared                       4.20.0
# aext-toolbox                      4.20.0
# aiobotocore                       2.25.0
# aiodns                            3.5.0
# aiohappyeyeballs                  2.6.1
# aiohttp                           3.13.2
# aioitertools                      0.12.0
# aiosignal                         1.4.0
# alabaster                         0.7.16
# alembic                           1.18.3
# altair                            5.5.0
# ...

# %%
import requests

# %%
requests.get??
# Out:
# Signature: requests.get(url, params=None, **kwargs)
# Source:
# def get(url, params=None, **kwargs):
#     r"""Sends a GET request.
#
#     :param url: URL for the new :class:`Request` object.
#     :param params: (optional) Dictionary, list of tuples or bytes to send
#         in the query string for the :class:`Request`.
#     :param \*\*kwargs: Optional arguments that ``request`` takes.
#     :return: :class:`Response <Response>` object
#     :rtype: requests.Response
#     """
#
#     return request("get", url, params=params, **kwargs)
# File:      c:\users\adu27\anaconda3\lib\site-packages\requests\api.py
# Type:      function

# %%
iss_url = "https://api.wheretheiss.at/v1/satellites/25544"

# %%
my_header = {'Accept': 'application/json'}

# %%
results = requests.get(iss_url, headers=my_header)

# %%
print(results)
print(results.json())
# Out:
# <Response [200]>
# {'name': 'iss', 'id': 25544, 'latitude': 29.435621247534, 'longitude': -139.29848504073, 'altitude': 419.09844539251, 'velocity': 27595.756254328, 'visibility': 'eclipsed', 'footprint': 4502.8739084934, 'timestamp': 1771247043, 'daynum': 2461088.0444792, 'solar_lat': -12.214741594015, 'solar_lon': 347.4943142431, 'units': 'kilometers'}

# %%
results_json = results.json()
print(results_json['latitude'])
# Out:
# 29.435621247534

# %%
with open('mission_iss.json', 'w') as f:
    f.write(results.text)

# %%
with open("mission_iss.json", "r") as f:
    print(f.read() + "\n")
# Out:
# {"name":"iss","id":25544,"latitude":29.435621247534,"longitude":-139.29848504073,"altitude":419.09844539251,"velocity":27595.756254328,"visibility":"eclipsed","footprint":4502.8739084934,"timestamp":1771247043,"daynum":2461088.0444792,"solar_lat":-12.214741594015,"solar_lon":347.4943142431,"units":"kilometers"}

# %%
new_set = {1,2,3,4,5,6}

# %%
try:
    new_set[4] = 94
except Exception as e:
    print("error happened: " + str(e) + "Thanks you")
# Out:
# error happened: 'set' object does not support item assignmentThanks you

# %%
try:
   new_set.add(1)
except Exception as e:
    print("error happened: " + str(e) + "Thanks you")

# %%
# !pip install numpy

# %%
import numpy as np

# %%
data  = np.random.rand(2,3,4)
zeroes = np.zeros((2,2,2))
full = np.full((2,2,2),99)
ones = np.ones((2,2,2))

# %%
data
# Out:
# array([[[0.92306582, 0.83650394, 0.2618831 , 0.08998855],
#         [0.94616314, 0.72870566, 0.41878072, 0.04124031],
#         [0.89919291, 0.9540704 , 0.29389345, 0.76901   ]],
#
#        [[0.12361429, 0.60746182, 0.93617242, 0.33131388],
#         [0.42647941, 0.75423691, 0.75023574, 0.02462898],
#         [0.15510451, 0.05541313, 0.98224354, 0.31367864]]])

# %%
zeroes
# Out:
# array([[[0., 0.],
#         [0., 0.]],
#
#        [[0., 0.],
#         [0., 0.]]])

# %%
full
# Out:
# array([[[99, 99],
#         [99, 99]],
#
#        [[99, 99],
#         [99, 99]]])

# %%
ones
# Out:
# array([[[1., 1.],
#         [1., 1.]],
#
#        [[1., 1.],
#         [1., 1.]]])

# %%
arr = np.array([[1,2,3,4,5],[12,13,14,15,16]])

# %%
arr
# Out:
# array([[ 1,  2,  3,  4,  5],
#        [12, 13, 14, 15, 16]])

# %%
shape = data.shape

# %%
size = data.size
types = data.dtype

# %%
shape
# Out:
# (2, 3, 4)

# %%
size
# Out:
# 24

# %%
types
# Out:
# dtype('float64')

# %%
list1 = np.random.rand(10)

# %%
list1
# Out:
# array([0.58289746, 0.11463725, 0.43042449, 0.72711918, 0.98441574,
#        0.12701555, 0.36702745, 0.76172038, 0.20446944, 0.09593098])

# %%
list2 = np.random.rand(10)

# %%
list2
# Out:
# array([0.21939666, 0.6156786 , 0.60419376, 0.41023524, 0.90260633,
#        0.28179509, 0.3476647 , 0.32542179, 0.70348654, 0.465784  ])

# %%
add = np.add(list1,list2)
sub = np.subtract(list1,list2)
div = np.divide(list1,list2)
mul = np.multiply(list1,list2)
dot = np.dot(list1,list2)

# %%
dot
# Out:
# np.float64(2.2451549180547823)

# %%
add
# Out:
# array([0.80229413, 0.73031585, 1.03461825, 1.13735442, 1.88702208,
#        0.40881064, 0.71469215, 1.08714216, 0.90795598, 0.56171497])

# %%
div
# Out:
# array([2.65682009, 0.18619659, 0.7123948 , 1.77244447, 1.09063687,
#        0.45073729, 1.05569377, 2.34071719, 0.29065154, 0.20595593])

# %%
sqrt = np.sqrt(list1)

# %%
sqrt
# Out:
# array([0.76347722, 0.33858124, 0.65606744, 0.85271284, 0.99217727,
#        0.35639242, 0.60582791, 0.87276593, 0.45218298, 0.30972726])

# %%
import pandas as pd

# %%
df = pd.read_csv('telco_churn.csv')

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# ...

# %%
df.head(10)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
# 6    MA             121        510                 No             Yes
# 7    MO             147        415                Yes              No
# 8    LA             117        408                 No              No
# 9    WV             141        415                Yes             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# ...

# %%
tempdict  = {'col1': [1,2,3], 'col2': [4,5,6], 'col3': [7,8,9]}

# %%
dictdf = pd.DataFrame.from_dict(tempdict)

# %%
df.head(10)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
# 6    MA             121        510                 No             Yes
# 7    MO             147        415                Yes              No
# 8    LA             117        408                 No              No
# 9    WV             141        415                Yes             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# ...

# %%
dictdf.head()
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %%
df.tail(10)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3323    IN             117        415                 No              No
# 3324    WV             159        415                 No              No
# 3325    OH              78        408                 No              No
# 3326    OH              96        415                 No              No
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3323                      0              118.4            126.0
# ...

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls           float64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls           float64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls         float64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls    float64
# Churn                      object
# dtype: object

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3323.000000
# mean       101.064806   437.182418               8.099010         179.787150
# std         39.822106    42.371290              13.688365          54.419625
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.500000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3323.000000       3315.000000        3324.000000      3325.000000
# mean        100.456214         30.557831         201.033935       100.110677
# ...

# %%
df.describe(include='object')
# Out:
#        State International plan Voice mail plan  Churn
# count   3333               3333            3333   3325
# unique    51                  2               2      2
# top       WV                 No              No  False
# freq     106               3010            2411   2842

# %%
df.State
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %%
df['International plan']
# Out:
# 0        No
# 1        No
# 2        No
# 3       Yes
# 4       Yes
#        ...
# 3328     No
# 3329     No
# 3330     No
# 3331    Yes
# 3332     No
# Name: International plan, Length: 3333, dtype: object

# %%
df[['State', 'International plan']]
# Out:
#      State International plan
# 0       KS                 No
# 1       OH                 No
# 2       NJ                 No
# 3       OH                Yes
# 4       OK                Yes
# ...    ...                ...
# 3328    AZ                 No
# 3329    WV                 No
# 3330    RI                 No
# 3331    CT                Yes
# 3332    TN                 No
#
# [3333 rows x 2 columns]

# %%
df.Churn.unique()
# Out:
# array([False, nan, True], dtype=object)

# %%
df[(df['International plan']=='No')&(df['Churn']==True)]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 10      IN              65        415                 No              No
# 15      NY             161        415                 No              No
# 21      CO              77        408                 No              No
# 33      AZ              12        408                 No              No
# 48      ID             119        415                 No              No
# ...    ...             ...        ...                ...             ...
# 3280    AR              76        408                 No              No
# 3287    KS             170        415                 No             Yes
# 3301    CA              84        415                 No              No
# 3322    MD              62        408                 No              No
# 3323    IN             117        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.iloc[14]
# Out:
# State                        IA
# Account length               62
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes         307.2
# Total eve calls            76.0
# Total eve charge          26.11
# Total night minutes       203.0
# Total night calls          99.0
# Total night charge         9.14
# Total intl minutes         13.1
# Total intl calls              6
# Total intl charge          3.54
# Customer service calls      4.0
# Churn                     False
# Name: 14, dtype: object

# %%
df.iloc[14,-1]
# Out:
# False

# %%
df.iloc[23:33]
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 23    SC             111        415                 No              No
# 24    VA             132        510                 No              No
# 25    NE             174        415                 No              No
# 26    WY              57        408                 No             Yes
# 27    MT              54        408                 No              No
# 28    MO              20        415                 No              No
# 29    HI              49        510                 No              No
# 30    IL             142        415                 No              No
# 31    NH              75        510                 No              No
# 32    LA             172        408                 No              No
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 23                      0              110.4            103.0
# ...

# %%
state = df.copy()
state.set_index('State', inplace=True)

# %%
state.head()
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# KS                128        415                 No             Yes
# OH                107        415                 No             Yes
# NJ                137        415                 No              No
# OH                 84        408                Yes              No
# OK                 75        415                Yes              No
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# KS                        25              265.1            110.0
# OH                        26              161.6            123.0
# NJ                         0              243.4            114.0
# OH                         0              299.4             71.0
# OK                         0              166.7            113.0
#
#        Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# State
# ...

# %%
state.loc['OH']
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# OH                107        415                 No             Yes
# OH                 84        408                Yes              No
# OH                 65        408                 No              No
# OH                 83        415                 No              No
# OH                 63        415                Yes             Yes
# ...               ...        ...                ...             ...
# OH                160        415                 No              No
# OH                 88        408                 No              No
# OH                106        415                 No             Yes
# OH                 78        408                 No              No
# OH                 96        415                 No              No
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# OH                        26              161.6            123.0
# ...

# %%
df.isnull().sum()
# Out:
# State                      0
# Account length             0
# Area code                  0
# International plan         0
# Voice mail plan            0
# Number vmail messages      0
# Total day minutes         10
# Total day calls           10
# Total day charge          18
# Total eve minutes          9
# Total eve calls            8
# Total eve charge           0
# Total night minutes        0
# Total night calls          1
# Total night charge         0
# Total intl minutes         0
# Total intl calls           0
# Total intl charge          5
# Customer service calls     5
# Churn                      8
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
df.drop('Area code',axis=1 )
# Out:
#      State  Account length International plan Voice mail plan  \
# 0       KS             128                 No             Yes
# 1       OH             107                 No             Yes
# 2       NJ             137                 No              No
# 3       OH              84                Yes              No
# 4       OK              75                Yes              No
# ...    ...             ...                ...             ...
# 3328    AZ             192                 No             Yes
# 3329    WV              68                 No              No
# 3330    RI              28                 No              No
# 3331    CT             184                Yes              No
# 3332    TN              74                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1            110.0
# 1                        26              161.6            123.0
# ...

# %%
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd

# %matplotlib inline

plt.style.use('default')

# %%
x = [1,2,3,4,5]
y = [2,4,6,8,10]
plt.plot(x,y)
plt.plot(y,x)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Simple line graph")
plt.show()

# %%
fig ,ax = plt.subplots()
ax.plot(x,y)
ax.set_xlabel("X Axis")
ax.set_ylabel('Y Axis')
ax.set_title('Line PLot')
plt.show()

# %%
x = np.linspace(0, 10,100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.sin(x)
plt.figure(figsize=(10, 6))
plt.plot(x,y1,y2,y3)   
plt.xlabel("X Axis")
plt.ylabel("sin(x)")
plt.title('Sine COSINE SINE Wave')
plt.grid(True)
plt.show()

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score  
from sklearn.preprocessing import PolynomialFeatures
from sklearn.ensemble import (GradientBoostingRegressor, 
                              RandomForestRegressor)


housing  = datasets.fetch_california_housing()

x = housing.data
y = housing.target


poly = PolynomialFeatures()
x = poly.fit_transform(x)
  

x_train ,x_test, y_train, y_test =train_test_split(
                x,
                y,
                test_size=0.2,
                random_state=450
                )

LR = LinearRegression()
GBR = GradientBoostingRegressor()
RFR = RandomForestRegressor()

for i in [LR, GBR, RFR]:
    i.fit(x_train, y_train)
    y_pred = i.predict(x_test)
    r2 = r2_score(y_test, y_pred)
    print(i, r2)
# Out:
# LinearRegression() 0.4520826683877577
# GradientBoostingRegressor() 0.8033792545648346
# RandomForestRegressor() 0.816701997277262
